# %%
# Matplotlib Subplots for Multiple Data Sets
# Description: Create subplots using Matplotlib to display the bar plot for product sales and the scatter plot for
# height vs. weight side by side.
import matplotlib.pyplot as plt

# Data for bar plot
products = ['A', 'B', 'C', 'D', 'E']
sales = [23, 75, 57, 90, 65]

# Data for scatter plot
heights = [160, 170, 165, 180, 175]
weights = [55, 65, 60, 80, 76]

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot on first subplot
axs[0].bar(products, sales, color='lightgreen', edgecolor='black')
axs[0].set_title('Product Sales')
axs[0].set_xlabel('Product')
axs[0].set_ylabel('Sales (in thousands)')

# Scatter plot on second subplot
axs[1].scatter(heights, weights, color='orange', edgecolor='black')
axs[1].set_title('Height vs. Weight')
axs[1].set_xlabel('Height (cm)')
axs[1].set_ylabel('Weight (kg)')

plt.tight_layout()
plt.show()
