# %%
# Question: Data Quality Automation Tools - Introduction to Great Expectations
# Description: Set up a simple Great Expectations check for missing values in a numeric column.

# !pip install great_expectations

# STEP 2: Required imports
import os
import great_expectations as gx
from great_expectations.checkpoint import Checkpoint
from great_expectations.core.batch import RuntimeBatchRequest

# STEP 3: Initialize file-based context
context = gx.get_context(mode="file")

# STEP 4: Add a Pandas datasource with runtime data connector
datasource_name = "my_csv_datasource"
if datasource_name not in [ds["name"] for ds in context.list_datasources()]:
    context.add_datasource(
        name=datasource_name,
        class_name="Datasource",
        execution_engine={"class_name": "PandasExecutionEngine"},
        data_connectors={
            "default_runtime_data_connector_name": {
                "class_name": "RuntimeDataConnector",
                "batch_identifiers": ["default_identifier_name"]
            }
        }
    )

# STEP 5: Create Expectation Suite
suite_name = "expect_no_missing_values"
if suite_name not in [s.expectation_suite_name for s in context.list_expectation_suites()]:
    context.add_expectation_suite(expectation_suite_name=suite_name)

# STEP 6: Set path to the CSV
csv_path = "data/score_data.csv"  # Ensure this path exists and file is present

# STEP 7: Create RuntimeBatchRequest
batch_request = RuntimeBatchRequest(
    datasource_name=datasource_name,
    data_connector_name="default_runtime_data_connector_name",
    data_asset_name="score_data",  # this can be any name
    runtime_parameters={"path": csv_path},
    batch_identifiers={"default_identifier_name": "default_id"}
)

# STEP 8: Create Validator and Expectation
validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name=suite_name
)

# Add expectation to check for missing values
validator.expect_column_values_to_not_be_null("score")

# Save expectation suite
validator.save_expectation_suite()

# STEP 9: Validate data
checkpoint_result = validator.validate()
print(checkpoint_result)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting great_expectations
#   Downloading great_expectations-1.4.5-py3-none-any.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 11.7 MB/s eta 0:00:0000:0100:01
# Collecting mistune>=0.8.4
#   Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.9.0.post0)
# Collecting jsonschema>=2.5.1
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 14.0 MB/s eta 0:00:00
# Collecting requests>=2.20
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (25.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (4.13.2)
# Collecting altair<5.0.0,>=4.2.1
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 45.9 MB/s eta 0:00:00
# Collecting pandas<2.2,>=1.3.0
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 29.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (1.15.3)
# Requirement already satisfied: pyparsing>=2.4 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (3.2.3)
# Collecting cryptography>=3.2
#   Downloading cryptography-45.0.2-cp37-abi3-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 36.7 MB/s eta 0:00:0000:01m
# Collecting marshmallow<4.0.0,>=3.7.1
#   Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.10.7 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.11.4)
# Collecting posthog<4,>3
#   Downloading posthog-3.25.0-py2.py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 18.3 MB/s eta 0:00:00
# Collecting ruamel.yaml>=0.16
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 23.1 MB/s eta 0:00:00
# Collecting tzlocal>=1.2
#   Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Collecting jinja2>=3
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 25.2 MB/s eta 0:00:00
# Collecting tqdm>=4.59.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /home/vscode/.local/lib/python3.10/site-packages (from great_expectations) (2.2.6)
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting toolz
#   Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 11.6 MB/s eta 0:00:00
# Collecting cffi>=1.14
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 38.2 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 7.2 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.0/387.0 kB 55.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2025.2)
# Collecting numpy>=1.22.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 23.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tzdata>=2022.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2025.2)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting distro>=1.5.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from posthog<4,>3->great_expectations) (1.17.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic>=1.10.7->great_expectations) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic>=1.10.7->great_expectations) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from pydantic>=1.10.7->great_expectations) (0.4.1)
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 16.4 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 20.7 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 kB 29.0 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 26.7 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 39.6 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 22.8 MB/s eta 0:00:00
# Installing collected packages: monotonic, urllib3, tzlocal, tqdm, toolz, ruamel.yaml.clib, rpds-py, pycparser, numpy, mistune, marshmallow, MarkupSafe, idna, entrypoints, distro, charset-normalizer, certifi, backoff, attrs, ruamel.yaml, requests, referencing, pandas, jinja2, cffi, posthog, jsonschema-specifications, cryptography, jsonschema, altair, great_expectations
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed MarkupSafe-3.0.2 altair-4.2.2 attrs-25.3.0 backoff-2.2.1 certifi-2025.4.26 cffi-1.17.1 charset-normalizer-3.4.2 cryptography-45.0.2 distro-1.9.0 entrypoints-0.4 great_expectations-1.4.5 idna-3.10 jinja2-3.1.6 jsonschema-4.23.0 jsonschema-specifications-2025.4.1 marshmallow-3.26.1 mistune-3.1.3 monotonic-1.6 numpy-1.26.4 pandas-2.1.4 posthog-3.25.0 pycparser-2.22 referencing-0.36.2 requests-2.32.3 rpds-py-0.25.1 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 toolz-1.0.0 tqdm-4.67.1 tzlocal-5.3.1 urllib3-2.4.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# DataContextError                          Traceback (most recent call last)
# Cell In[1], line 18
#      16 datasource_name = "my_csv_datasource"
#      17 if datasource_name not in [ds["name"] for ds in context.list_datasources()]:
# ---> 18     context.add_datasource(
#      19         name=datasource_name,
#      20         class_name="Datasource",
#      21         execution_engine={"class_name": "PandasExecutionEngine"},
#      22         data_connectors={
#      23             "default_runtime_data_connector_name": {
#      24                 "class_name": "RuntimeDataConnector",
#      25                 "batch_identifiers": ["default_identifier_name"]
#      26             }
#      27         }
#      28     )
#      30 # STEP 5: Create Expectation Suite
#      31 suite_name = "expect_no_missing_values"
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:718, in AbstractDataContext.add_datasource(self, name, initialize, datasource, **kwargs)
#     691 @new_argument(
#     692     argument_name="datasource",
#     693     version="0.15.49",
#    (...)
#     701     **kwargs,
#     702 ) -> FluentDatasource | None:
#     703     """Add a new Datasource to the data context, with configuration provided as kwargs.
#     704
#     705     --Documentation--
#    (...)
#     716         Datasource instance added.
#     717     """
# --> 718     return self._add_datasource(
#     719         name=name,
#     720         initialize=initialize,
#     721         datasource=datasource,
#     722         **kwargs,
#     723     )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:758, in AbstractDataContext._add_datasource(self, name, initialize, datasource, **kwargs)
#     754     self._add_fluent_datasource(
#     755         datasource=datasource,
#     756     )
#     757 else:
# --> 758     raise DataContextError("Datasource is not a FluentDatasource")  # noqa: TRY003 # FIXME CoP
#     759 return datasource
#
# DataContextError: Datasource is not a FluentDatasource

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'id': [1, 2, 3, 4, 5],
    'score': [85, None, 90, 88, None]  # Missing values in 'score'
}

df = pd.DataFrame(data)

# Save DataFrame to a CSV file
df.to_csv('score_data.csv', index=False)

print("CSV file 'score_data.csv' created successfully.")
# Out:
# CSV file 'score_data.csv' created successfully.
